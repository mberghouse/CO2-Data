# %%
#
import os
os.chdir('/Users/marcb/Desktop')
os.getcwd()
# Out:
# 'C:\\Users\\marcb\\Desktop'

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
infile1 = "CO2 Data/raw_data/Calhoun/R1C1/cczo_hydroprobe_data.xlsx"
infile2 = "CO2 Data/raw_data/Calhoun/R1C1/CCZO_soil_gas_data.xlsx" 


df1 = pd.read_excel(infile1, na_values='NAN',  parse_dates=[0], index_col=1) 
df2 = pd.read_excel(infile2, na_values='NAN',  parse_dates=[0], index_col=0)

# %%
df1=df1.loc[df1['Plot'] == 'R1C1'] 
df1
# Out:
#             Plot  Std Count  Depth (cm)  Counts  R (Counts/Std)
# Date
# 2016-10-06  R1C1       7518         -30    9887          1.3151
# 2016-10-06  R1C1       7518         -60   10387          1.3816
# 2016-10-06  R1C1       7518         -90   10173          1.3532
# 2016-10-06  R1C1       7518        -120   10603          1.4103
# 2016-10-06  R1C1       7518        -150   10086          1.3416
# ...          ...        ...         ...     ...             ...
# 2018-02-22  R1C1       7545        -360    8099          1.0734
# 2018-02-22  R1C1       7545        -390    8268          1.0958
# 2018-02-22  R1C1       7545        -420    8123          1.0766
# 2018-02-22  R1C1       7545        -450    7922          1.0500
# 2018-02-22  R1C1       7545        -480    8891          1.1784
#
# [368 rows x 5 columns]

# %%
df2=df2.loc[df2['Site'] == 'R1'] 
df2=df2.loc[df2['Plot'] == 'C1']

# %%
df2=df2.drop(columns='Comments')
df2=df2.drop(columns='Time')

df2=df2.drop(columns='Site')
df2=df2.drop(columns='Plot')
df2
# Out:
#            Depth (m) O2_pct CO2_pct GC_N2O_ppm GC_CH4_ppm GC_CO2_pct
# Date
# 2015-07-31       0.5    NaN     NaN        NaN        NaN        NaN
# 2015-07-31       1.5    NaN     NaN        NaN        NaN        NaN
# 2015-07-31         3   18.9     NaN    2.46017   0.217497     2.3779
# 2015-07-31         5   18.6     NaN     2.9087   0.192666    2.61673
# 2015-08-20         0     20   0.041        NaN        NaN        NaN
# ...              ...    ...     ...        ...        ...        ...
# 2017-07-26         0   20.7   0.038        NaN        NaN        NaN
# 2017-07-26       0.5   15.2   4.832        NaN        NaN        NaN
# 2017-07-26       1.5   15.5   3.229        NaN        NaN        NaN
# 2017-07-26         3     19    2.09        NaN        NaN        NaN
# 2017-07-26         5   19.1   1.956        NaN        NaN        NaN
#
# [159 rows x 6 columns]

# %%
#df=pd.concat([df2,df3], sort=False)
#df.columns=['ApogeeTemp_10cm.deg.C', 'ApogeeTemp_30cm.deg.C', 'ApogeeTemp_60cm.deg.C', 'ApogeeTemp_60(2)cm.deg.C', 'O2_10cm.percent.0-100','O2_30cm.percent.0-100', 'O2_60cm.percent.0-100', 'O2_60(2)cm.percent.0-100', 'CO2_10cm.ppm', 'CO2_30cm.ppm', 'CO2_60cm.ppm', 'CO2_60(2)cm.ppm', 'WaterPotential_10cm.kPa','WaterPotential_30cm.kPa', 'DecagonMPS6Temp_10cm.deg.C','DecagonMPS6Temp_30cm.deg.C', 'SoilMoisture_10cm.m3m3', 'SoilMoisture_30cm.m3m3', 'SoilMoisture_60cm.m3m3', 'SoilMoisture_60(2)cm.m3m3', 'BulkEC_10cm.dS/m', 'BulkEC_30cm.dS/m', 'BulkEC_60cm.dS/m', 'BulkEC_60(2)cm.dS/m', 'Decagon5TETemp_10cm.deg.C','Decagon5TETemp_30cm.deg.C', 'Decagon5TETemp_60cm.deg.C', 'Decagon5TETemp_60(2)cm.deg.C','ReductionPotential_10cm.mV', 'ReductionPotential_5cm.mV', 'ReductionPotential_30cm.mV', 'ReductionPotential_60cm.mV' ]
#df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b40a0f50dbb5> in <module>
# ----> 1 df=pd.concat([df2,df3], sort=False)
#       2 #df.columns=['ApogeeTemp_10cm.deg.C', 'ApogeeTemp_30cm.deg.C', 'ApogeeTemp_60cm.deg.C', 'ApogeeTemp_60(2)cm.deg.C', 'O2_10cm.percent.0-100','O2_30cm.percent.0-100', 'O2_60cm.percent.0-100', 'O2_60(2)cm.percent.0-100', 'CO2_10cm.ppm', 'CO2_30cm.ppm', 'CO2_60cm.ppm', 'CO2_60(2)cm.ppm', 'WaterPotential_10cm.kPa','WaterPotential_30cm.kPa', 'DecagonMPS6Temp_10cm.deg.C','DecagonMPS6Temp_30cm.deg.C', 'SoilMoisture_10cm.m3m3', 'SoilMoisture_30cm.m3m3', 'SoilMoisture_60cm.m3m3', 'SoilMoisture_60(2)cm.m3m3', 'BulkEC_10cm.dS/m', 'BulkEC_30cm.dS/m', 'BulkEC_60cm.dS/m', 'BulkEC_60(2)cm.dS/m', 'Decagon5TETemp_10cm.deg.C','Decagon5TETemp_30cm.deg.C', 'Decagon5TETemp_60cm.deg.C', 'Decagon5TETemp_60(2)cm.deg.C','ReductionPotential_10cm.mV', 'ReductionPotential_5cm.mV', 'ReductionPotential_30cm.mV', 'ReductionPotential_60cm.mV' ]
#       3 df
#
# NameError: name 'df3' is not defined

# %%
#Corrections to whole DataFrame
#df=df.fillna(value=0)

df2.mask(df2=='FL', inplace=True)
df2=df2.astype(float)
df2
# Out:
# C:\Users\marcb\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#             Depth (m)  O2_pct  CO2_pct  GC_N2O_ppm  GC_CH4_ppm  GC_CO2_pct
# Date
# 2015-07-31        0.5     NaN      NaN         NaN         NaN         NaN
# 2015-07-31        1.5     NaN      NaN         NaN         NaN         NaN
# 2015-07-31        3.0    18.9      NaN    2.460172    0.217497    2.377899
# 2015-07-31        5.0    18.6      NaN    2.908705    0.192666    2.616732
# 2015-08-20        0.0    20.0    0.041         NaN         NaN         NaN
# ...               ...     ...      ...         ...         ...         ...
# 2017-07-26        0.0    20.7    0.038         NaN         NaN         NaN
# 2017-07-26        0.5    15.2    4.832         NaN         NaN         NaN
# 2017-07-26        1.5    15.5    3.229         NaN         NaN         NaN
# 2017-07-26        3.0    19.0    2.090         NaN         NaN         NaN
# 2017-07-26        5.0    19.1    1.956         NaN         NaN         NaN
#
# [159 rows x 6 columns]

# %%
#plt.show()
#df.plot(use_index=True, y='CO2_pct')
#df.plot(use_index=True, y='CO2_50cm_Avg')
#df.plot(use_index=True, y='CO2_150cm_Avg')

# %%
#Plot CO2 data


plt.show()
df.plot(use_index=True, y='VWC_25cm_Avg')
df.plot(use_index=True, y='VWC_50cm_Avg')

df.plot(use_index=True, y='EC_25cm_Avg')
df.plot(use_index=True, y='EC_50cm_Avg')

# %%
df=df2
df['CO2_2_0cm.pct']=np.where(df['Depth (m)'] == 0, df['CO2_pct'], np.nan)
df['CO2_2_50cm.pct']=np.where(df['Depth (m)'] == .5, df['CO2_pct'], np.nan)
df['CO2_2_150cm.pct']=np.where(df['Depth (m)'] == 1.5, df['CO2_pct'], np.nan)
df['CO2_2_300cm.pct']=np.where(df['Depth (m)'] == 3, df['CO2_pct'], np.nan)
df['CO2_2_500cm.pct']=np.where(df['Depth (m)'] == 5, df['CO2_pct'], np.nan)



df

plt.show()
df.plot(use_index=True, y='GC_N2O_ppm')
df.plot(use_index=True, y='GC_CH4_ppm')
df.plot(use_index=True, y='GC_CO2_pct')
df.plot(use_index=True, y='CO2_2_0cm.pct')
df.plot(use_index=True, y='CO2_2_50cm.pct')
df.plot(use_index=True, y='CO2_2_150cm.pct')
df.plot(use_index=True, y='CO2_2_300cm.pct')
df.plot(use_index=True, y='CO2_2_500cm.pct')


df.plot(use_index=True, y='O2_pct')
df.plot(use_index=True, y='CO2_pct')

# %%
plt.show()
df.plot(use_index=True, y='WaterPotential_10cm.kPa')
df.plot(use_index=True, y='WaterPotential_30cm.kPa')

# %%
plt.show()
df.plot(use_index=True, y='T_O2_50cm_degC_Avg')
df.plot(use_index=True, y='T_O2_150cm_degC_Avg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'T_O2_50cm_degC_Avg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-0c0b0cb2ba28> in <module>
#       1 plt.show()
# ----> 2 df.plot(use_index=True, y='T_O2_50cm_degC_Avg')
#       3 df.plot(use_index=True, y='T_O2_150cm_degC_Avg')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     831
#     832                 # don't overwrite
# --> 833                 data = data[y].copy()
#     834
#     835                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'T_O2_50cm_degC_Avg'

# %%
output=df.copy()
today = dt.date.today()
outfile = 'CO2 Data/processed_data/Calhoun/R1C2_processed.csv'
output.to_csv(outfile, na_rep=-99999, index_label='DateTime.EST')

# %%
output
# Out:
#                      Depth (m)  O2_pct  CO2_pct  GC_N2O_ppm  GC_CH4_ppm  \
# 2015-07-31 00:00:00        0.5     NaN      NaN         NaN         NaN
# 2015-07-31 00:00:00        1.5     NaN      NaN         NaN         NaN
# 2015-07-31 00:00:00        3.0    18.9      NaN    2.460172    0.217497
# 2015-07-31 00:00:00        5.0    18.6      NaN    2.908705    0.192666
# 2015-08-20 00:00:00        0.0    20.0    0.041         NaN         NaN
# ...                        ...     ...      ...         ...         ...
# 2019-06-26 15:30:00        NaN     NaN      NaN         NaN         NaN
# 2019-06-26 16:00:00        NaN     NaN      NaN         NaN         NaN
# 2019-06-26 16:30:00        NaN     NaN      NaN         NaN         NaN
# 2019-06-26 17:00:00        NaN     NaN      NaN         NaN         NaN
# 2019-06-26 17:30:00        NaN     NaN      NaN         NaN         NaN
#
#                      GC_CO2_pct  BattV_Avg  PTemp_C_Avg  CO2_50cm_Avg  \
# 2015-07-31 00:00:00         NaN        NaN          NaN           NaN
# 2015-07-31 00:00:00         NaN        NaN          NaN           NaN
# 2015-07-31 00:00:00    2.377899        NaN          NaN           NaN
# 2015-07-31 00:00:00    2.616732        NaN          NaN           NaN
# 2015-08-20 00:00:00         NaN        NaN          NaN           NaN
# ...                         ...        ...          ...           ...
# 2019-06-26 15:30:00         NaN      12.89        39.10         5.011
# 2019-06-26 16:00:00         NaN      12.89        38.99         5.011
# 2019-06-26 16:30:00         NaN      12.86        38.28         5.010
# 2019-06-26 17:00:00         NaN      12.91        37.61         5.010
# 2019-06-26 17:30:00         NaN      12.94        36.90         5.009
#
#                      CO2_150cm_Avg  T108_C_0cm_Avg  Temp_C_box_Avg  \
# 2015-07-31 00:00:00            NaN             NaN             NaN
# 2015-07-31 00:00:00            NaN             NaN             NaN
# 2015-07-31 00:00:00            NaN             NaN             NaN
# 2015-07-31 00:00:00            NaN             NaN             NaN
# 2015-08-20 00:00:00            NaN             NaN             NaN
# ...                            ...             ...             ...
# 2019-06-26 15:30:00          5.007           27.51           42.00
# 2019-06-26 16:00:00          5.006           27.73           41.21
# 2019-06-26 16:30:00          5.006           27.92           39.79
# 2019-06-26 17:00:00          5.006           28.08           39.46
# 2019-06-26 17:30:00          5.006           28.20           37.82
#
#                      VWC_50cm_Avg  EC_50cm_Avg  T_TDR50cm_Avg  P_50cm_Avg  \
# 2015-07-31 00:00:00           NaN          NaN            NaN         NaN
# 2015-07-31 00:00:00           NaN          NaN            NaN         NaN
# 2015-07-31 00:00:00           NaN          NaN            NaN         NaN
# 2015-07-31 00:00:00           NaN          NaN            NaN         NaN
# 2015-08-20 00:00:00           NaN          NaN            NaN         NaN
# ...                           ...          ...            ...         ...
# 2019-06-26 15:30:00         0.403        0.069          26.19       25.28
# 2019-06-26 16:00:00         0.403        0.069          26.18       25.28
# 2019-06-26 16:30:00         0.403        0.069          26.16       25.28
# 2019-06-26 17:00:00         0.403        0.069          26.15       25.28
# 2019-06-26 17:30:00         0.403        0.070          26.14       25.28
#
#                      PA_50cm_Avg  VR_50cm_Avg  T_O2_50cm_degC_Avg  \
# 2015-07-31 00:00:00          NaN          NaN                 NaN
# 2015-07-31 00:00:00          NaN          NaN                 NaN
# 2015-07-31 00:00:00          NaN          NaN                 NaN
# 2015-07-31 00:00:00          NaN          NaN                 NaN
# 2015-08-20 00:00:00          NaN          NaN                 NaN
# ...                          ...          ...                 ...
# 2019-06-26 15:30:00        1.859        1.088               27.31
# 2019-06-26 16:00:00        1.859        1.088               27.29
# 2019-06-26 16:30:00        1.859        1.088               27.28
# 2019-06-26 17:00:00        1.859        1.088               27.28
# 2019-06-26 17:30:00        1.859        1.088               27.28
#
#                      T_O2_150cm_degC_Avg  BattV_Std  PTemp_C_Std  \
# 2015-07-31 00:00:00                  NaN        NaN          NaN
# 2015-07-31 00:00:00                  NaN        NaN          NaN
# 2015-07-31 00:00:00                  NaN        NaN          NaN
# 2015-07-31 00:00:00                  NaN        NaN          NaN
# 2015-08-20 00:00:00                  NaN        NaN          NaN
# ...                                  ...        ...          ...
# 2019-06-26 15:30:00                24.14      0.075        0.055
# 2019-06-26 16:00:00                24.16      0.045        0.096
# 2019-06-26 16:30:00                24.16      0.011        0.265
# 2019-06-26 17:00:00                24.17      0.043        0.069
# 2019-06-26 17:30:00                24.17      0.024        0.338
#
#                      CO2_50cm_Std  CO2_150cm_Std  T108_C_0cm_Std  \
# 2015-07-31 00:00:00           NaN            NaN             NaN
# 2015-07-31 00:00:00           NaN            NaN             NaN
# 2015-07-31 00:00:00           NaN            NaN             NaN
# 2015-07-31 00:00:00           NaN            NaN             NaN
# 2015-08-20 00:00:00           NaN            NaN             NaN
# ...                           ...            ...             ...
# 2019-06-26 15:30:00           0.0          0.001           0.062
# 2019-06-26 16:00:00           0.0          0.000           0.057
# 2019-06-26 16:30:00           0.0          0.000           0.057
# 2019-06-26 17:00:00           0.0          0.001           0.051
# 2019-06-26 17:30:00           0.0          0.000           0.034
#
#                      Temp_C_box_Std  VWC_50cm_Std  EC_50cm_Std  T_TDR50cm_Std  \
# 2015-07-31 00:00:00             NaN           NaN          NaN            NaN
# 2015-07-31 00:00:00             NaN           NaN          NaN            NaN
# 2015-07-31 00:00:00             NaN           NaN          NaN            NaN
# 2015-07-31 00:00:00             NaN           NaN          NaN            NaN
# 2015-08-20 00:00:00             NaN           NaN          NaN            NaN
# ...                             ...           ...          ...            ...
# 2019-06-26 15:30:00           0.394           0.0          0.0          0.003
# 2019-06-26 16:00:00           0.160           0.0          0.0          0.028
# 2019-06-26 16:30:00           0.117           0.0          0.0          0.006
# 2019-06-26 17:00:00           0.378           0.0          0.0          0.006
# 2019-06-26 17:30:00           0.144           0.0          0.0          0.006
#
#                      P_50cm_Std  PA_50cm_Std  VR_50cm_Std  T_O2_50cm_degC_Std  \
# 2015-07-31 00:00:00         NaN          NaN          NaN                 NaN
# 2015-07-31 00:00:00         NaN          NaN          NaN                 NaN
# 2015-07-31 00:00:00         NaN          NaN          NaN                 NaN
# 2015-07-31 00:00:00         NaN          NaN          NaN                 NaN
# 2015-08-20 00:00:00         NaN          NaN          NaN                 NaN
# ...                         ...          ...          ...                 ...
# 2019-06-26 15:30:00         0.0          0.0          0.0               0.000
# 2019-06-26 16:00:00         0.0          0.0          0.0               0.008
# 2019-06-26 16:30:00         0.0          0.0          0.0               0.015
# 2019-06-26 17:00:00         0.0          0.0          0.0               0.000
# 2019-06-26 17:30:00         0.0          0.0          0.0               0.000
#
#                      T_O2_150cm_degC_Std  pct_O2_50cm_Avg  pct_O2_150cm_Avg  \
# 2015-07-31 00:00:00                  NaN              NaN               NaN
# 2015-07-31 00:00:00                  NaN              NaN               NaN
# 2015-07-31 00:00:00                  NaN              NaN               NaN
# 2015-07-31 00:00:00                  NaN              NaN               NaN
# 2015-08-20 00:00:00                  NaN              NaN               NaN
# ...                                  ...              ...               ...
# 2019-06-26 15:30:00                0.000            12.69             0.104
# 2019-06-26 16:00:00                0.000            12.74             0.104
# 2019-06-26 16:30:00                0.007            12.74             0.104
# 2019-06-26 17:00:00                0.000            12.64             0.104
# 2019-06-26 17:30:00                0.000            12.59             0.104
#
#                      T_TDR25cm_Std  T_TDR25cm_Avg  VWC_25cm_Avg  VWC_25cm_Std  \
# 2015-07-31 00:00:00            NaN            NaN           NaN           NaN
# 2015-07-31 00:00:00            NaN            NaN           NaN           NaN
# 2015-07-31 00:00:00            NaN            NaN           NaN           NaN
# 2015-07-31 00:00:00            NaN            NaN           NaN           NaN
# 2015-08-20 00:00:00            NaN            NaN           NaN           NaN
# ...                            ...            ...           ...           ...
# 2019-06-26 15:30:00          0.019          26.72         0.411           0.0
# 2019-06-26 16:00:00          0.046          26.84         0.411           0.0
# 2019-06-26 16:30:00          0.031          26.99         0.411           0.0
# 2019-06-26 17:00:00          0.033          27.11         0.411           0.0
# 2019-06-26 17:30:00          0.044          27.24         0.411           0.0
#
#                      EC_25cm_Avg  EC_25cm_Std  P_25cm_Std  P_25cm_Avg  \
# 2015-07-31 00:00:00          NaN          NaN         NaN         NaN
# 2015-07-31 00:00:00          NaN          NaN         NaN         NaN
# 2015-07-31 00:00:00          NaN          NaN         NaN         NaN
# 2015-07-31 00:00:00          NaN          NaN         NaN         NaN
# 2015-08-20 00:00:00          NaN          NaN         NaN         NaN
# ...                          ...          ...         ...         ...
# 2019-06-26 15:30:00        0.087          0.0         0.0       26.07
# 2019-06-26 16:00:00        0.087          0.0         0.0       26.07
# 2019-06-26 16:30:00        0.088          0.0         0.0       26.07
# 2019-06-26 17:00:00        0.088          0.0         0.0       26.07
# 2019-06-26 17:30:00        0.088          0.0         0.0       26.07
#
#                      PA_25cm_Avg  PA_25cm_Std  VR_25cm_Std  VR_25cm_Avg  \
# 2015-07-31 00:00:00          NaN          NaN          NaN          NaN
# 2015-07-31 00:00:00          NaN          NaN          NaN          NaN
# 2015-07-31 00:00:00          NaN          NaN          NaN          NaN
# 2015-07-31 00:00:00          NaN          NaN          NaN          NaN
# 2015-08-20 00:00:00          NaN          NaN          NaN          NaN
# ...                          ...          ...          ...          ...
# 2019-06-26 15:30:00        1.868          0.0          0.0        1.111
# 2019-06-26 16:00:00        1.868          0.0          0.0        1.111
# 2019-06-26 16:30:00        1.868          0.0          0.0        1.112
# 2019-06-26 17:00:00        1.868          0.0          0.0        1.112
# 2019-06-26 17:30:00        1.868          0.0          0.0        1.112
#
#                      pct_O2_50cm_Std  pct_O2_150cm_Std  CO2_2_0cm.pct  \
# 2015-07-31 00:00:00              NaN               NaN            NaN
# 2015-07-31 00:00:00              NaN               NaN            NaN
# 2015-07-31 00:00:00              NaN               NaN            NaN
# 2015-07-31 00:00:00              NaN               NaN            NaN
# 2015-08-20 00:00:00              NaN               NaN          0.041
# ...                              ...               ...            ...
# 2019-06-26 15:30:00            0.071               0.0            NaN
# 2019-06-26 16:00:00            0.000               0.0            NaN
# 2019-06-26 16:30:00            0.000               0.0            NaN
# 2019-06-26 17:00:00            0.071               0.0            NaN
# 2019-06-26 17:30:00            0.000               0.0            NaN
#
#                      CO2_2_50cm.pct  CO2_2_150cm.pct  CO2_2_300cm.pct  \
# 2015-07-31 00:00:00             NaN              NaN              NaN
# 2015-07-31 00:00:00             NaN              NaN              NaN
# 2015-07-31 00:00:00             NaN              NaN              NaN
# 2015-07-31 00:00:00             NaN              NaN              NaN
# 2015-08-20 00:00:00             NaN              NaN              NaN
# ...                             ...              ...              ...
# 2019-06-26 15:30:00             NaN              NaN              NaN
# 2019-06-26 16:00:00             NaN              NaN              NaN
# 2019-06-26 16:30:00             NaN              NaN              NaN
# 2019-06-26 17:00:00             NaN              NaN              NaN
# 2019-06-26 17:30:00             NaN              NaN              NaN
#
#                      CO2_2_500cm.pct
# 2015-07-31 00:00:00              NaN
# 2015-07-31 00:00:00              NaN
# 2015-07-31 00:00:00              NaN
# 2015-07-31 00:00:00              NaN
# 2015-08-20 00:00:00              NaN
# ...                              ...
# 2019-06-26 15:30:00              NaN
# 2019-06-26 16:00:00              NaN
# 2019-06-26 16:30:00              NaN
# 2019-06-26 17:00:00              NaN
# 2019-06-26 17:30:00              NaN
#
# [45336 rows x 55 columns]
